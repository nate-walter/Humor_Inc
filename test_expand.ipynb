# %%
from faker import Faker
import pandas as pd
import random

# Initialize Faker
fake = Faker()

# Number of records to generate (this is a small sample; you can scale this up on your machine)
num_records = 100_000

# %%
# Lists to store data
company_ids = list(range(1, num_records + 1))
names = [fake.company() + " " + random.choice(["Unlimited", "LLC", "Corp", "GmbH", "Limited", "Inc."]) for _ in range(num_records)]
descriptions = [fake.catch_phrase() for _ in range(num_records)]
industries = [random.choice(["Technology", "Healthcare", "Finance", "Retail", "Food & Beverage", "Entertainment"]) for _ in range(num_records)]
founded_dates = [fake.date_between(start_date="-50y", end_date="today") for _ in range(num_records)]
headquarters = [fake.city() for _ in range(num_records)]
ceo_names = [fake.name() for _ in range(num_records)]
revenue_mil = [round(random.uniform(10, 500), 2) for _ in range(num_records)]
stock_symbols = [fake.lexify(text="????", letters="ABCDEFGHIJKLMNOPQRSTUVWXYZ") for _ in range(num_records)]
employee_count = [random.randint(50, 5000) for _ in range(num_records)]
market_cap_bil = [round(random.uniform(1, 50), 2) for _ in range(num_records)]
hq_countries = [fake.country() for _ in range(num_records)]

# Create DataFrame
companies_df = pd.DataFrame({
    "CompanyID": company_ids,
    "Name": names,
    "Description": descriptions,
    "Industry": industries,
    "FoundedDate": founded_dates,
    "Headquarters": headquarters,
    "CEO_Name": ceo_names,
    "Revenue_Mil": revenue_mil,
    "Stock_Symbol": stock_symbols,
    "Employee_Count": employee_count,
    "Market_Cap_Bil": market_cap_bil,
    "HQ_Country": hq_countries
})

companies_df.head()
# Out:
#    CompanyID                              Name  \
# 0          1            Thomas-Stone Unlimited
# 1          2            Hooper-Andrews Limited
# 2          3                 Davis-Thomas Inc.
# 3          4  Copeland, Anderson and Bond GmbH
# 4          5               Johns Inc Unlimited
#
#                                 Description         Industry FoundedDate  \
# 0           Seamless reciprocal contingency       Technology  2014-05-09
# 1     Ameliorated next generation help-desk    Entertainment  1978-03-09
# 2  Ergonomic reciprocal process improvement  Food & Beverage  2009-07-04
# 3                Profound mobile complexity  Food & Beverage  1997-02-02
# 4                  Diverse responsive array  Food & Beverage  1989-08-17
#
#         Headquarters         CEO_Name  Revenue_Mil Stock_Symbol  \
# 0  East Crystalmouth  Walter Mckenzie       454.70         EPIT
# 1         Port James     Teresa Patel       493.79         SGFQ
# 2       Port Michael  Robert Crawford       172.83         UEAD
# 3       Perrychester   Jacob Bartlett       169.99         KYZD
# 4      New Alexander   Jessica Carter       172.36         CSMI
#
#    Employee_Count  Market_Cap_Bil    HQ_Country
# 0            4854            2.70         Malta
# 1            4446           35.17    Mozambique
# 2            1035           26.58  South Africa
# 3            3644            2.01    Montenegro
# 4            2916           44.89  Turkmenistan

# %%
companies_df.tail(20)
# Out:
#        CompanyID                                  Name  \
# 99980      99981                    Zimmerman Ltd Corp
# 99981      99982     Solomon, Sanchez and Shaw Limited
# 99982      99983                    Riley-Buchanan LLC
# 99983      99984      Bentley, Pierce and Gilbert Inc.
# 99984      99985                     Green-Gibson GmbH
# 99985      99986     Anderson, Smith and Short Limited
# 99986      99987                   Salazar PLC Limited
# 99987      99988                     Ray-Crawford Inc.
# 99988      99989  Benton, Henson and Valentine Limited
# 99989      99990    Porter, Williams and Petersen Inc.
# 99990      99991                     Thompson LLC Inc.
# 99991      99992           Mason, Wilson and Roth GmbH
# 99992      99993                     Anderson Inc Inc.
# 99993      99994                      Smith Group Corp
# 99994      99995             Fox, Jensen and Cruz Inc.
# 99995      99996                       Moore-Webb Inc.
# 99996      99997                        Bryant PLC LLC
# 99997      99998                       Pace-Krause LLC
# 99998      99999        Wolfe, Wilkinson and Owens LLC
# 99999     100000                     Taylor Group GmbH
#
#                                              Description         Industry  \
# 99980                  Triple-buffered tertiary function  Food & Beverage
# 99981  Fully-configurable human-resource Local Area N...           Retail
# 99982                Switchable systemic instruction set  Food & Beverage
# 99983                        Pre-emptive static alliance           Retail
# 99984             Profit-focused even-keeled methodology       Healthcare
# 99985                     Versatile content-based matrix       Healthcare
# 99986                     Streamlined high-level circuit  Food & Beverage
# 99987                   Quality-focused holistic adapter    Entertainment
# 99988                  Customer-focused didactic project       Healthcare
# 99989                Multi-lateral interactive interface    Entertainment
# 99990           Enterprise-wide executive info-mediaries  Food & Beverage
# 99991                    Cross-platform local time-frame    Entertainment
# 99992                Exclusive intangible info-mediaries    Entertainment
# 99993                  Organic client-driven parallelism       Technology
# 99994                     Phased discrete info-mediaries    Entertainment
# 99995                    Switchable optimizing hierarchy       Technology
# 99996       Horizontal clear-thinking Local Area Network    Entertainment
# 99997            Configurable client-driven service-desk          Finance
# 99998                   Seamless non-volatile monitoring    Entertainment
# 99999           Reduced 6thgeneration Local Area Network           Retail
#
#       FoundedDate      Headquarters            CEO_Name  Revenue_Mil  \
# 99980  2017-03-28        Fosterfort  Patrick Cunningham       480.15
# 99981  1977-04-20   South Frankstad           Paul Hall       112.26
# 99982  1989-08-28         New Helen         Kevin Berry        99.28
# 99983  1979-02-11    East Thomaston      Randy Galloway       243.27
# 99984  2012-12-08  New Kimberlytown  Ms. Jessica Jarvis       254.65
# 99985  1993-02-21       Waltonville       Keith Estrada       254.61
# 99986  1973-12-06  East Rachelburgh    Patricia Gilbert        61.94
# 99987  2012-05-17      Samanthaland          Amanda Lee       104.53
# 99988  2004-12-05         Port Sara         David Wells       433.16
# 99989  1977-02-19   Port Ronaldland        Linda Morton       309.68
# 99990  1996-10-08       East Daniel      Adrian Stewart       228.77
# 99991  1991-12-28      Lake Timothy        Dennis Scott       166.68
# 99992  2018-01-26           Wangton           Joel Ward       453.35
# 99993  1987-02-25        Lake James        Marie Cooper       491.62
# 99994  1988-06-03         Anneburgh         Kelly Green       242.33
# 99995  2010-06-27          Jodyside   Kevin Blankenship       340.89
# 99996  2021-10-29     West Bobbyton      David Johnston        66.11
# 99997  2023-08-04        Garciatown       Abigail Terry        20.17
# 99998  1979-03-16        New Steven    Nicole Rodriguez       438.35
# 99999  1992-02-24        South Luis       Courtney Rios       417.85
#
#       Stock_Symbol  Employee_Count  Market_Cap_Bil                HQ_Country
# 99980         HCRG            3666           20.91                    Jordan
# 99981         ILBC             344           40.08                   Lebanon
# 99982         LMHU            3338           27.11                   Grenada
# 99983         SUFJ            2424           36.19                  Tanzania
# 99984         ZJXT            2512           38.34    British Virgin Islands
# 99985         MKSB            4660            9.14                   Ireland
# 99986         JNUN            1157           13.62  Northern Mariana Islands
# 99987         ELLX            4913           19.11                     Korea
# 99988         ZFDA            4306           31.19                    Guyana
# 99989         GUDL            1724           34.64                   Uruguay
# 99990         WDLR            4900           28.91                     Gabon
# 99991         NCAN            3841           32.60                   Romania
# 99992         YQYU            4158            5.09          French Polynesia
# 99993         HZFX            3947           21.83                  Zimbabwe
# 99994         ZRTI            4438           47.17                  Anguilla
# 99995         UPCE            1685           36.19  Turks and Caicos Islands
# 99996         YYGV            3664           23.03                  Guernsey
# 99997         RGXY             959           29.15                   Bahrain
# 99998         SIYT            2975           33.81       Antigua and Barbuda
# 99999         NOKA            1453           29.64               Switzerland
